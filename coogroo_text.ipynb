# %%
from pymongo import MongoClient
from preprocessor import *
from cogroo_interface import Cogroo
# Out:
# X:\Programs\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
cogroo = Cogroo.Instance()

client = MongoClient('localhost', 27017)
db = client["discursoDB"]
discursos = db["discursos"]

discursos_list = discursos.find({"Conteudo": {
    "$ne": ""
}}, {"Conteudo": 1, "_id": 0})

# %%
text = discursos_list[0]["Conteudo"]

# %%
cogroo.analyze(text).sentences[6].tokens
# Out:
# [Senadores#n M=P,
#  ,#, -,
#  é#v-fin PR=3S=IND,
#  meu#pron-det M=S,
#  propósito#n M=S,
#  ,#, -,
#  a#prp -,
#  o#art M=S,
#  assumir#v-inf -,
#  hoje#adv -,
#  esta#pron-det F=S,
#  tribuna#n F=S,
#  ,#, -,
#  informar#v-inf -,
#  a#art F=S,
#  Presidência#n F=S,
#  de#prp -,
#  esta#pron-det F=S,
#  Casa#prop F=S,
#  e#conj-c -,
#  meus#pron-det M=P,
#  Colegas_Senadores#n M=P,
#  que#pron-indp M=P,
#  se#pron-pers M=3S=ACC,
#  realizou#v-fin PS=3S=IND,
#  ontem#adv -,
#  a#art F=S,
#  reunião#n F=S,
#  final#adj F=S,
#  de#prp -,
#  a#art F=S,
#  Comissão_de_Julgamento#prop F=S,
#  de#prp -,
#  o#art M=S,
#  Prêmio_Cruz#prop M=S,
#  e#conj-c -,
#  Sousa#prop -,
#  ,#, -,
#  de#prp -,
#  a#art F=S,
#  qual#pron-det F=S,
#  tive#v-fin PS=1S=IND,
#  a#art F=S,
#  honra#n F=S,
#  de#prp -,
#  participar#v-inf -,
#  a#prp -,
#  o#art M=S,
#  lado#n M=S,
#  de#prp -,
#  o#art M=S,
#  Senador_Esperidião_Amin#prop M=S,
#  ,#, -,
#  de#prp -,
#  o#art M=S,
#  Deputado_Paulo_Gouvêa#prop M=S,
#  ,#, -,
#  de#prp -,
#  o#art M=S,
#  Poeta_Gerardo_Mello_Mourão#prop M=S,
#  e#conj-c -,
#  de#prp -,
#  o#art M=S,
#  Professor_Iaponan_Soares#n M=S,
#  .#. -]
